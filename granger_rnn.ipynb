# %%
import pickle
import pandas as pd
from helpermodules.correlation_study import CorrelationAnalysis
from helpermodules.nonlin_granger_casuality import NonlinearNNGrangerCausalityAnalysis

# Load the pickle file
with open('data/pickle_files/cleaned_nasdaq_dataframe.pkl', 'rb') as file:
    df = pickle.load(file)
# Out:
# TF float8 patch failed: cannot import name 'float8_e4m3b11fnuz' from 'tensorflow.python.framework.dtypes' (c:\Users\giuli\Repositories\nasdaq_causal-analysis_lstm\venv\Lib\site-packages\tensorflow\python\framework\dtypes.py)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as pd
#       3 from helpermodules.correlation_study import CorrelationAnalysis
# ----> 4 from helpermodules.nonlin_granger_casuality import NonlinearNNGrangerCausalityAnalysis
#       6 # Load the pickle file
#       7 with open('data/pickle_files/cleaned_nasdaq_dataframe.pkl', 'rb') as file:
#
# File c:\Users\giuli\Repositories\nasdaq_causal-analysis_lstm\helpermodules\nonlin_granger_casuality.py:22
#      20 import pandas as pd
#      21 import numpy as np
# ---> 22 import keras
#      23 from nonlincausality import nonlincausalityNN as nlc_nn
# ...

# %%
# Import your class
nlc_analysis = NonlinearNNGrangerCausalityAnalysis(dataframe=df)

# Run the nonlinear causality analysis
results = nlc_analysis.calculate_nonlinear_nn_causality()

significant = nlc_analysis.significant_causality_pairs(alpha=0.05)
